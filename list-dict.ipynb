# %%
# A list with different scalar values (like strings, integers, booleans, floats)
sonic_speedsters = ["Sonic", 300, True, 3.14, "Gotta go fast!", False]
# Out:
# 3.14

# %%
# A list containing a short list (nested list)
mario_adventures = ["Mario", "Level 1", ["Jump", "Coin", "Mushroom"], "Boss fight"]
# Out:
# n

# %%
# A dictionary with scalar values (strings, ints, booleans, etc.)

sonic_stats = {
    "name": "Sonic",
    "rings": 100,
    "is_hero": True,
    "speed": 765.45,
    "enemy": "Eggman"
}
# Out:
# 100

# %%
# A list containing a short flat dictionary (a dict inside)

bbt_geek_lst = ["Sheldon", "Physics", {"iq": 187, "hobby": "Trains", "catchphrase": "Bazinga!", "girlfriend": "Amy"}, "Comic store"]

print(bbt_geek_lst[2]["iq"])
# Out:
# 187

# %%
# A dictionary containing a short flat list and a short flat dictionary.
bbt_geek_dict = {
    "name": "Leonard",
    "job": "Physicist",
    "friends": ["Sheldon", "Howard", "Raj", "Amy", "Bernadette", "Stuart"],
    "traits": {"glasses": True, "lactose_intolerant": True, "girlfriend": "Penny"},
    "apartment": "4A"
}

print(bbt_geek_dict["traits"]["girlfriend"])
# Out:
# Penny
